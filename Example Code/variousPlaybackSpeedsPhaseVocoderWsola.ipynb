# %%
import os
os.chdir("..")
import context
context.get()

import magSonify
import datetime
import numpy
from IPython.display import Audio

# %%
mag = magSonify.THEMISdata()
mag.importCDAS(
    datetime.datetime(2008,12,7),
    datetime.datetime(2008,12,8)
)
mag.defaultProcessing()
pol = mag.magneticFieldMeanFieldCoordinates.extractKey(1)

# %%
vo_8_pol = pol.copy()
vo_8_pol.phaseVocoderStretch(8)

Audio(vo_8_pol.x,rate=44100)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
